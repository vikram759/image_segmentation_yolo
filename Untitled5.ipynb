# %% [markdown]
# <a href="https://colab.research.google.com/github/vikram759/image_segmentation_yolo/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.colab import drive
drive.mount('/content/drive')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.1/112.6 GB disk)

# %%
import os

# %%
# Out:
# mkdir: cannot create directory ‘/kaggle/working/ultralytics/mydata’: No such file or directory

# %%
from google.colab import files
uploaded = files.upload() #               upload zip file sent to u
#also upload other 2 files sent to u in the file icon on the left side, and u dont have to do nothing else just keep running all the codes
# Out:
#      <input type="file" id="files-8517c099-cb32-457b-b933-a511a7499015" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8517c099-cb32-457b-b933-a511a7499015">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip mydata.zip -d /content/
# Out:
# Archive:  mydata.zip
#    creating: /content/mydata/images/
#    creating: /content/mydata/images/test/
#   inflating: /content/mydata/images/test/1 (18)_1649990925.jpg
#   inflating: /content/mydata/images/test/1 (4)_1649859559.jpg
#   inflating: /content/mydata/images/test/1 (45)_1650423922.jpg
#   inflating: /content/mydata/images/test/2 (17)_1649991010.jpg
#   inflating: /content/mydata/images/test/2 (43)_1650424073.jpg
#   inflating: /content/mydata/images/test/2 (50)_1650423534.jpg
#   inflating: /content/mydata/images/test/3 (26)_1649991291.jpg
#   inflating: /content/mydata/images/test/3 (45)_1650423933.jpg
#   inflating: /content/mydata/images/test/3 (48)_1650423600.jpg
#   inflating: /content/mydata/images/test/4 (13)_1649859983.jpg
#   inflating: /content/mydata/images/test/4 (32)_1650425271.jpg
#   inflating: /content/mydata/images/test/4 (47)_1650423582.jpg
#   inflating: /content/mydata/images/test/5 (20)_1649991626.jpg
# ...

# %%
os.makedirs("/content/ultralytics/mydata", exist_ok=True)

# %%
os.makedirs("/content/ultralytics/mydata/images")
os.makedirs("/content/ultralytics/mydata/labels")
os.makedirs("/content/ultralytics/mydata/images/val")
os.makedirs("/content/ultralytics/mydata/images/test")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-3870554840.py in <cell line: 0>()
# ----> 1 os.makedirs("/content/ultralytics/mydata/images")
#       2 os.makedirs("/content/ultralytics/mydata/labels")
#       3 os.makedirs("/content/ultralytics/mydata/images/val")
#       4 os.makedirs("/content/ultralytics/mydata/images/test")
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '/content/ultralytics/mydata/images'

# %%
os.makedirs("/content/ultralytics/mydata/images/val")

# %%
os.makedirs("/content/ultralytics/mydata/labels/train")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipython-input-2256864214.py in <cell line: 0>()
# ----> 1 os.makedirs("/content/ultralytics/mydata/labels/train")
#       2 os.makedirs("/content/ultralytics/mydata/labels/val")
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '/content/ultralytics/mydata/labels/train'

# %%
os.makedirs("/content/ultralytics/mydata/labels/val")

# %%
from distutils.dir_util import copy_tree

# %%
fromDir = '/content/drive/MyDrive/mydata/images/train'
toDirectory = '/content/ultralytics/mydata/images/train'
copy_tree(fromDir, toDirectory)
# Out:
# ['/content/ultralytics/mydata/images/train/4 (37)_1650424576.jpg',
#  '/content/ultralytics/mydata/images/train/4 (39)_1650424362.jpg',
#  '/content/ultralytics/mydata/images/train/5 (28)_1649991690.jpg',
#  '/content/ultralytics/mydata/images/train/1 (22)_1649990940.jpg',
#  '/content/ultralytics/mydata/images/train/4 (42)_1650424016.jpg',
#  '/content/ultralytics/mydata/images/train/4 (28)_1649991521.jpg',
#  '/content/ultralytics/mydata/images/train/6 (15)_1649991703.jpg',
#  '/content/ultralytics/mydata/images/train/1 (3)_1649859553.jpg',
#  '/content/ultralytics/mydata/images/train/1 (9)_1649859582.jpg',
#  '/content/ultralytics/mydata/images/train/2 (51)_1650423471.jpg',
#  '/content/ultralytics/mydata/images/train/6_1649857903.jpg',
#  '/content/ultralytics/mydata/images/train/6 (42)_1650424052.jpg',
#  '/content/ultralytics/mydata/images/train/2 (45)_1650423926.jpg',
#  '/content/ultralytics/mydata/images/train/6 (9)_1649860156.jpg',
# ...

# %%
fromDir = '/content/drive/MyDrive/mydata/images/test'
toDirectory = '/content/ultralytics/mydata/images/val'
copy_tree(fromDir, toDirectory)
# Out:
# ['/content/ultralytics/mydata/images/val/2 (43)_1650424073.jpg',
#  '/content/ultralytics/mydata/images/val/4 (47)_1650423582.jpg',
#  '/content/ultralytics/mydata/images/val/2 (50)_1650423534.jpg',
#  '/content/ultralytics/mydata/images/val/1 (4)_1649859559.jpg',
#  '/content/ultralytics/mydata/images/val/3 (48)_1650423600.jpg',
#  '/content/ultralytics/mydata/images/val/5 (20)_1649991626.jpg',
#  '/content/ultralytics/mydata/images/val/1 (18)_1649990925.jpg',
#  '/content/ultralytics/mydata/images/val/1 (45)_1650423922.jpg',
#  '/content/ultralytics/mydata/images/val/4 (32)_1650425271.jpg',
#  '/content/ultralytics/mydata/images/val/2 (17)_1649991010.jpg',
#  '/content/ultralytics/mydata/images/val/6 (10)_1649860162.jpg',
#  '/content/ultralytics/mydata/images/val/6 (26)_1649991767.jpg',
#  '/content/ultralytics/mydata/images/val/5 (29)_1650425730.jpg',
#  '/content/ultralytics/mydata/images/val/6 (17)_1649991717.jpg',
# ...

# %%
fromDir = '/content/drive/MyDrive/mydata/labels/train'
toDirectory = '/content/ultralytics/mydata/labels/train'
copy_tree(fromDir, toDirectory)
# Out:
# ['/content/ultralytics/mydata/labels/train/5 (5)_1649860045.txt',
#  '/content/ultralytics/mydata/labels/train/5 (42)_1650424039.txt',
#  '/content/ultralytics/mydata/labels/train/5 (3)_1649859998.txt',
#  '/content/ultralytics/mydata/labels/train/6 (8)_1649860151.txt',
#  '/content/ultralytics/mydata/labels/train/4 (34)_1650425090.txt',
#  '/content/ultralytics/mydata/labels/train/5_1649857893.txt',
#  '/content/ultralytics/mydata/labels/train/5 (43)_1650423955.txt',
#  '/content/ultralytics/mydata/labels/train/2 (32)_1650425575.txt',
#  '/content/ultralytics/mydata/labels/train/5 (22)_1649991649.txt',
#  '/content/ultralytics/mydata/labels/train/4 (36)_1650424653.txt',
#  '/content/ultralytics/mydata/labels/train/2 (49)_1650423572.txt',
#  '/content/ultralytics/mydata/labels/train/5 (17)_1649991604.txt',
#  '/content/ultralytics/mydata/labels/train/3 (4)_1649859817.txt',
#  '/content/ultralytics/mydata/labels/train/1 (40)_1650424406.txt',
# ...

# %%
fromDir = '/content/drive/MyDrive/mydata/labels/test'
toDirectory = '/content/ultralytics/mydata/labels/val'
copy_tree(fromDir, toDirectory)
# Out:
# ['/content/ultralytics/mydata/labels/val/1 (45)_1650423922.txt',
#  '/content/ultralytics/mydata/labels/val/5 (41)_1650424112.txt',
#  '/content/ultralytics/mydata/labels/val/3 (48)_1650423600.txt',
#  '/content/ultralytics/mydata/labels/val/3 (26)_1649991291.txt',
#  '/content/ultralytics/mydata/labels/val/2 (43)_1650424073.txt',
#  '/content/ultralytics/mydata/labels/val/6 (26)_1649991767.txt',
#  '/content/ultralytics/mydata/labels/val/5 (29)_1650425730.txt',
#  '/content/ultralytics/mydata/labels/val/3 (45)_1650423933.txt',
#  '/content/ultralytics/mydata/labels/val/4 (47)_1650423582.txt',
#  '/content/ultralytics/mydata/labels/val/2 (17)_1649991010.txt',
#  '/content/ultralytics/mydata/labels/val/4 (32)_1650425271.txt',
#  '/content/ultralytics/mydata/labels/val/2 (50)_1650423534.txt',
#  '/content/ultralytics/mydata/labels/val/1 (4)_1649859559.txt',
#  '/content/ultralytics/mydata/labels/val/6 (39)_1650424380.txt',
# ...

# %%
# Train YOLOv8n on COCO128 for 300 epochs
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/mydata.yaml epochs=10 imgsz=640 batch=32 cache=disk
# Out:
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/mydata.yaml imgsz=640
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3010.0±996.5 MB/s, size: 201.5 KB)
# val: Scanning /content/ultralytics/mydata/labels/val.cache... 19 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 19/19 268.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         19        459       0.97      0.983       0.99      0.794
# Speed: 0.2ms preprocess, 23.4ms inference, 0.0ms loss, 7.3ms postprocess per image
# Results saved to /content/runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
